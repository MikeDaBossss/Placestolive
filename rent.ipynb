# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeDaBossss/Placestolive/blob/master/rent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload = files.upload()#'/content/drive/My Drive/jobs_indeed.csv'
# Out:
#      <input type="file" id="files-13037474-c4a1-4631-823e-b2d921c9c280" name="files[]" multiple disabled />
#      <output id="result-13037474-c4a1-4631-823e-b2d921c9c280">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
upload
# Out:
# {}

# %%
import pandas as pd
countyrent = pd.read_excel('/Median Rent By county.xls')

# %%
countyrent.to_excel('/content/drive/My Drive/MedianRentCounty.xls')

# %%
countyrent
# Out:
#         fips2010  rent50_0  rent50_1  ...  Unnamed: 18  Unnamed: 19  Unnamed: 20
# 0     7200999999       319       337  ...          NaN           AR          NaN
# 1     7201999999       319       337  ...          NaN           PR          NaN
# 2     7203999999       319       337  ...          NaN           TN          NaN
# 3     7209599999       319       337  ...          NaN           MO          NaN
# 4     7210799999       319       337  ...          NaN           WV          NaN
# ...          ...       ...       ...  ...          ...          ...          ...
# 4765  2301347962       749       754  ...          NaN          NaN          NaN
# 4766  2301541280       751       797  ...          NaN          NaN          NaN
# 4767  3300942820       760       885  ...          NaN          NaN          NaN
# 4768  2300742765       585       625  ...          NaN          NaN          NaN
# 4769  2302911755       653       657  ...          NaN          NaN          NaN
#
# ...

# %%
import folium
from folium import plugins
m = folium.Map([42, -80.6298], zoom_start=11)
m.add_children(plugins.HeatMap(stationArr, radius=15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-5fade2ef5561> in <module>()
#       2 from folium import plugins
#       3 m = folium.Map([42, -80.6298], zoom_start=11)
# ----> 4 m.add_children(plugins.HeatMap(stationArr, radius=15))
#
# NameError: name 'stationArr' is not defined

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="specify_your_app_name_here")
location = geolocator.geocode("Aibonito Municipio")
print(location.address)
# Out:
# Aibonito, Puerto Rico, 00705, United States of America

# %%
countyrent['cntyname']
# Out:
# 0           Aibonito Municipio
# 1       Barranquitas Municipio
# 2             Ciales Municipio
# 3            Maunabo Municipio
# 4           Orocovis Municipio
#                  ...
# 4765               Knox County
# 4766            Lincoln County
# 4767            Grafton County
# 4768           Franklin County
# 4769         Washington County
# Name: cntyname, Length: 4770, dtype: object

# %%
lat = []
lon = []

for name in countyrent['cntyname'] : 
  print(name)
  try:
    lat.append(geolocator.geocode(name).latitude)
    lon.append(geolocator.geocode(name).longitude)
  except:
    lat.append(0)
    lon.append(0)
    print('error')
countyrent['lat'] = lat
countyrent['lon'] = lon
# Out:
# Streaming output truncated to the last 5000 lines.
# error
# Humboldt County
# error
# Neosho County
# error
# Telfair County
# error
# Rutland County
# error
# Smith County
# error
# Benton County
# error
# Fairfield County
# error
# Mercer County
# error
# Pike County
# error
# Gogebic County
# error
# Dixie County
# error
# Radford city
# error
# Torrance County
# error
# Cumberland County
# error
# Lewis County
# error
# Iowa County
# error
# Knott County
# error
# Clark County
# error
# Norfolk County
# error
# Richland County
# error
# Bristol County
# error
# Floyd County
# error
# Osage County
# error
# Essex County
# error
# Rabun County
# error
# Jackson Parish
# error
# Idaho County
# error
# Alleghany County
# error
# Brooks County
# error
# Kanabec County
# error
# Richland County
# error
# Vermillion County
# error
# Park County
# error
# Aitkin County
# error
# Worcester County
# error
# Ashland County
# error
# Newport County
# error
# Baker County
# error
# ...

# %%
#this api did not work even though it has worked in the past for me.

# %%
from geopy.geocoders import Pelias
geolocat = Pelias(timeout=.1)
location = geolocator.geocode("Aibonito Municipio")
print(location.address)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b9062b9a25ee> in <module>()
#       1 from geopy.geocoders import Pelias
# ----> 2 geolocat = Pelias(timeout=.1)
#       3 location = geolocator.geocode("Aibonito Municipio")
#       4 print(location.address)
#
# TypeError: __init__() missing 1 required positional argument: 'domain'

# %%
#other things that would be important to make the rent relative is the income that a person would be making. Let me download the data for different jobs in different locations
from google.colab import files
upload = files.upload()#'/content/drive/My Drive/jobs_indeed.csv'
# Out:
#      <input type="file" id="files-d567eb93-bedb-467a-ad20-57df9cba6636" name="files[]" multiple disabled />
#      <output id="result-d567eb93-bedb-467a-ad20-57df9cba6636">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving state_M2018_dl.xlsx to state_M2018_dl.xlsx

# %%
import pandas as pd
countyrent = pd.read_excel('state_M2018_dl.xlsx')
countyrent.to_excel('/content/drive/My Drive/JobIncomeperState.xlsx')

# %%
countyrent
# Out:
#        AREA  ST           STATE OCC_CODE  ... A_PCT75 A_PCT90 ANNUAL HOURLY
# 0         1  AL         Alabama  00-0000  ...   53310   79630    NaN    NaN
# 1         1  AL         Alabama  11-0000  ...  132860  187330    NaN    NaN
# 2         1  AL         Alabama  11-1011  ...       #       #    NaN    NaN
# 3         1  AL         Alabama  11-1021  ...  147250       #    NaN    NaN
# 4         1  AL         Alabama  11-1031  ...   32290   63390   True    NaN
# ...     ...  ..             ...      ...  ...     ...     ...    ...    ...
# 36892    78  VI  Virgin Islands  53-6031  ...   27330   30560    NaN    NaN
# 36893    78  VI  Virgin Islands  53-6099  ...   30590   44290    NaN    NaN
# 36894    78  VI  Virgin Islands  53-7051  ...   35980   41290    NaN    NaN
# 36895    78  VI  Virgin Islands  53-7062  ...   33640   41090    NaN    NaN
# 36896    78  VI  Virgin Islands  53-7064  ...   21070   24270    NaN    NaN
#
# [36897 rows x 25 columns]

# %%
countyrent[countyrent['OCC_TITLE'].str.contains('Analyst')]['OCC_TITLE'].unique()
# Out:
# array(['Management Analysts',
#        'Market Research Analysts and Marketing Specialists',
#        'Budget Analysts', 'Credit Analysts', 'Financial Analysts',
#        'Computer Systems Analysts', 'Information Security Analysts',
#        'Operations Research Analysts', 'Broadcast News Analysts'],
#       dtype=object)

# %%
#Budget Analyst is what I could do an analysis on 
countyrent[countyrent['OCC_TITLE'].str.contains('Budget Analyst')].sort_values(by='A_MEDIAN',ascending=False)
# Out:
#        AREA  ST                 STATE OCC_CODE  ... A_PCT75 A_PCT90 ANNUAL HOURLY
# 5592     11  DC  District of Columbia  13-2031  ...  113150  126060    NaN    NaN
# 13972    24  MD              Maryland  13-2031  ...  106680  124390    NaN    NaN
# 32451    51  VA              Virginia  13-2031  ...  109700  126070    NaN    NaN
# 2790      6  CA            California  13-2031  ...  108060  133020    NaN    NaN
# 14730    25  MA         Massachusetts  13-2031  ...  101840  122010    NaN    NaN
# 4358      9  CT           Connecticut  13-2031  ...   94940  109320    NaN    NaN
# 52        1  AL               Alabama  13-2031  ...  100810  116710    NaN    NaN
# 21103    34  NJ            New Jersey  13-2031  ...  100270  123710    NaN    NaN
# 27758    44  RI          Rhode Island  13-2031  ...   99380  117470    NaN    NaN
# 3603      8  CO              Colorado  13-2031  ...   95750  112640    NaN    NaN
# ...
